# %%
import pandas as pd

# plotting:
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")

# %%
data = pd.read_csv("../../data/dydx.csv")
data["diff_price_btc"] = data["price_btc_math"] - data["price_btc_numeric"]
data["diff_price_eth"] = data["price_eth_math"] - data["price_eth_numeric"]
data
# Out:
#        dollar_amt_in  price_btc_math  price_btc_numeric  price_eth_math  \
# 0           14127166    60562.339409       60562.339961     1689.133751
# 1           31039816    80589.374321       80589.374923     1944.413639
# 2           15612263    62230.785374       62230.785924     1711.849706
# 3           69059910   135241.177070      135241.177846     2511.387506
# 4           53290277    72092.485808       72092.486251     3502.096240
# ...              ...             ...                ...             ...
# 99995       11929745    58114.983765       58114.984298     1655.261314
# 99996       36699467    87856.628761       87856.629405     2029.083457
# 99997       74386089   144002.995049      144002.995820     2590.621920
# 99998       71772363   139669.122558      139669.123357     2551.742312
# 99999       59564366   120298.089409      120298.090131     2370.054646
#
#        price_eth_numeric  diff_price_btc  diff_price_eth
# ...

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 6))

ax.plot(
    data.dollar_amt_in,
    data.diff_price_btc,
    'b.',
    label="BTC"
)

ax.plot(
    data.dollar_amt_in,
    data.diff_price_eth,
    'r.',
    label="ETH"
)

ax.set_xlabel("Dollar amount in [$]", fontsize=20)
ax.set_ylabel("Price math - Price numeric [$]", fontsize=20)
ax.tick_params(axis='both', which='major', labelsize=20)
ax.tick_params(axis='x', which='major', colors='black')

ax.set_xscale("log")

ax.legend(fontsize=20)
